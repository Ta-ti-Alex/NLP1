# %% [markdown]
# ## ДЗ
# Разобраться с моделькой перевода (без механизма внимания) как она устроена, запустить для перевода с русского на английский (при желании можно взять другие пары языков)

# %% [markdown]
# # Neural machine translation

# %%
import tensorflow as tf

import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
from sklearn.model_selection import train_test_split

import unicodedata
import re
import numpy as np
import os
import io
import time

# %% [markdown]
# ## Download and prepare the dataset
#
# We'll use a language dataset provided by http://www.manythings.org/anki/

# %%
# !wget http://www.manythings.org/anki/rus-eng.zip
# Out:
# --2024-04-10 11:36:00--  http://www.manythings.org/anki/rus-eng.zip
# Resolving www.manythings.org (www.manythings.org)... 173.254.30.110
# Connecting to www.manythings.org (www.manythings.org)|173.254.30.110|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 16305013 (16M) [application/zip]
# Saving to: ‘rus-eng.zip’
#
# rus-eng.zip         100%[===================>]  15.55M  30.2MB/s    in 0.5s
#
# 2024-04-10 11:36:01 (30.2 MB/s) - ‘rus-eng.zip’ saved [16305013/16305013]

# %%
# !mkdir rus-eng
# !unzip rus-eng.zip -d rus-eng/
# Out:
# Archive:  rus-eng.zip
#   inflating: rus-eng/rus.txt
#   inflating: rus-eng/_about.txt

# %%
# !ls /content/rus-eng/ -lah
# Out:
# total 79M
# drwxr-xr-x 2 root root 4.0K Apr 10 11:36 .
# drwxr-xr-x 1 root root 4.0K Apr 10 11:36 ..
# -rw-r--r-- 1 root root 1.5K Apr  1 23:40 _about.txt
# -rw-r--r-- 1 root root  79M Apr  1 23:40 rus.txt

# %%
# Download the file
path_to_file = "/content/rus-eng/rus.txt"

# %%
def preprocess_sentence(w):
  w = w.lower().strip()

  # creating a space between a word and the punctuation following it
  # eg: "he is a boy." => "he is a boy ."
  # Reference:- https://stackoverflow.com/questions/3645931/python-padding-punctuation-with-white-spaces-keeping-punctuation
  w = re.sub(r"([?.!,])", r" \1 ", w)
  w = re.sub(r'[" "]+', " ", w)

  # replacing everything with space except (a-z, A-Z, ".", "?", "!", ",")
  w = re.sub(r"[^a-zA-Zа-яА-Я?.!,']+", " ", w)

  w = w.strip()

  # adding a start and an end token to the sentence
  # so that the model know when to start and stop predicting.
  w = '<start> ' + w + ' <end>'
  return w

# %%
preprocess_sentence("I can't go.")
# Out:
# "<start> i can't go . <end>"

# %%
# 1. Remove the accents
# 2. Clean the sentences
# 3. Return word pairs in the format: [ENG, RUS]
def create_dataset(path, num_examples):
  lines = io.open(path, encoding='UTF-8').read().strip().split('\n')

  word_pairs = [[preprocess_sentence(w) for w in l.split('\t')[:2]]  for l in lines[:num_examples]]

  return zip(*word_pairs)

# %%
en, ru = create_dataset(path_to_file, None)
print(en[0])
print(ru[0])
# Out:
# <start> go . <end>
# <start> марш ! <end>

# %%
def tokenize(lang):
  lang_tokenizer = tf.keras.preprocessing.text.Tokenizer(
      filters='')
  lang_tokenizer.fit_on_texts(lang)

  tensor = lang_tokenizer.texts_to_sequences(lang)

  tensor = tf.keras.preprocessing.sequence.pad_sequences(tensor,
                                                         padding='post')

  return tensor, lang_tokenizer

# %%
def load_dataset(path, num_examples=None):
  # creating cleaned input, output pairs
  targ_lang, inp_lang = create_dataset(path, num_examples)

  input_tensor, inp_lang_tokenizer = tokenize(inp_lang)
  target_tensor, targ_lang_tokenizer = tokenize(targ_lang)

  return input_tensor, target_tensor, inp_lang_tokenizer, targ_lang_tokenizer

# %% [markdown]
# ### Limit the size of the dataset to experiment faster (optional)

# %%
len(en), len(ru)
# Out:
# (496059, 496059)

# %%
# Try experimenting with the size of that dataset
num_examples = 100000
input_tensor, target_tensor, inp_lang, targ_lang = load_dataset(path_to_file, num_examples)

# Calculate max_length of the target tensors
max_length_targ, max_length_inp = target_tensor.shape[1], input_tensor.shape[1]

# %%
# Creating training and validation sets using an 80-20 split
input_tensor_train, input_tensor_val, target_tensor_train, target_tensor_val = train_test_split(input_tensor, target_tensor, test_size=0.2)

# Show length
print(len(input_tensor_train), len(target_tensor_train), len(input_tensor_val), len(target_tensor_val))
# Out:
# 80000 80000 20000 20000

# %%
def convert(lang, tensor):
  for t in tensor:
    if t!=0:
      print ("%d ----> %s" % (t, lang.index_word[t]))

# %%
print ("Input Language; index to word mapping")
convert(inp_lang, input_tensor_train[0])
print ()
print ("Target Language; index to word mapping")
convert(targ_lang, target_tensor_train[0])
# Out:
# Input Language; index to word mapping
# 1 ----> <start>
# 12730 ----> оцените
# 1808 ----> наше
# 3617 ----> приложение
# 3 ----> .
# 2 ----> <end>
#
# Target Language; index to word mapping
# 1 ----> <start>
# 5353 ----> rate
# 151 ----> our
# 2254 ----> app
# 3 ----> .
# 2 ----> <end>

# %% [markdown]
# ### Create a tf.data dataset

# %%
BUFFER_SIZE = len(input_tensor_train)
BATCH_SIZE = 64
steps_per_epoch = len(input_tensor_train)//BATCH_SIZE
embedding_dim = 300
units = 1024
vocab_inp_size = len(inp_lang.word_index)+1
vocab_tar_size = len(targ_lang.word_index)+1

dataset = tf.data.Dataset.from_tensor_slices((input_tensor_train, target_tensor_train)).shuffle(BUFFER_SIZE)
dataset = dataset.batch(BATCH_SIZE, drop_remainder=True)

# %%
example_input_batch, example_target_batch = next(iter(dataset))
example_input_batch.shape, example_target_batch.shape
# Out:
# (TensorShape([64, 15]), TensorShape([64, 10]))

# %% [markdown]
# **Для эксперимента возьму двунаправленный слой GRU**

# %%
from keras.layers import GRU, Concatenate

# %%
class Encoder(tf.keras.Model):
  def __init__(self, vocab_size, embedding_dim, enc_units, batch_sz):
    super(Encoder, self).__init__()
    self.batch_sz = batch_sz
    self.enc_units = enc_units
    self.embedding = tf.keras.layers.Embedding(vocab_size, embedding_dim)
    self.gru = tf.keras.layers.Bidirectional(GRU(self.enc_units,
                                   return_sequences=False,
                                   return_state=True,
                                   recurrent_initializer='glorot_uniform'))


  def call(self, x, hidden):
    x = self.embedding(x)
    output, state_frw, state_bcw = self.gru(x, initial_state = hidden)
    return state_frw, state_bcw

  # def initialize_hidden_state(self):
  #   return tf.zeros((self.batch_sz, self.enc_units))

  def initialize_hidden_state(self):
      return [tf.zeros((self.batch_sz, self.enc_units)) for i in range(2)]

# %%
encoder = Encoder(vocab_inp_size, embedding_dim, units, BATCH_SIZE)
# sample input
encoder = Encoder(vocab_inp_size, embedding_dim, units, BATCH_SIZE)
sample_hidden = encoder.initialize_hidden_state()
forward_hidden, backward_hidden = encoder(example_input_batch, sample_hidden)
print('Encoder forward_h shape: (batch size, units) {}'.format(forward_hidden.shape))
print('Encoder backward_h shape: (batch size, units) {}'.format(backward_hidden.shape))
# Out:
# Encoder forward_h shape: (batch size, units) (64, 1024)
# Encoder backward_h shape: (batch size, units) (64, 1024)

# %%
class Decoder(tf.keras.Model):
  def __init__(self, vocab_size, embedding_dim, dec_units, batch_sz):
    super(Decoder, self).__init__()
    self.batch_sz = batch_sz
    self.dec_units = dec_units
    self.embedding = tf.keras.layers.Embedding(vocab_size, embedding_dim)
    self.gru = tf.keras.layers.GRU(2*self.dec_units,
                                   return_sequences=True,
                                   return_state=True,
                                   recurrent_initializer='glorot_uniform')
    self.fc = tf.keras.layers.Dense(vocab_size)

  def call(self, x, encoder_fwd_state, encoder_back_state):
    # enc_output shape == (batch_size, max_length, hidden_size)

    # x shape after passing through embedding == (batch_size, 1, embedding_dim)
    x = self.embedding(x)

    # x shape after concatenation == (batch_size, 1, embedding_dim + hidden_size)

    # passing the concatenated vector to the GRU
    output, state = self.gru(x, initial_state=Concatenate(axis=-1)([encoder_fwd_state, encoder_back_state]))

    # output shape == (batch_size * 1, hidden_size)
    output = tf.reshape(output, (-1, output.shape[2]))

    # output shape == (batch_size, vocab)
    x = self.fc(output)

    return x, state

# %%
decoder = Decoder(vocab_tar_size, embedding_dim, units, BATCH_SIZE)

decoder_sample_x, decoder_sample_h = decoder(tf.random.uniform((BATCH_SIZE, 1)),
                                      forward_hidden, backward_hidden)

# %%
decoder_sample_x.shape
# Out:
# TensorShape([64, 7338])

# %%
decoder_sample_h.shape
# Out:
# TensorShape([64, 2048])

# %% [markdown]
# ## Define the optimizer and the loss function

# %%
optimizer = tf.keras.optimizers.Adam()

loss_object = tf.keras.losses.SparseCategoricalCrossentropy(
    from_logits=True, reduction='none')

def loss_function(real, pred):
  mask = tf.math.logical_not(tf.math.equal(real, 0))
  loss_ = loss_object(real, pred)

  mask = tf.cast(mask, dtype=loss_.dtype)
  loss_ *= mask

  return tf.reduce_mean(loss_)

# %% [markdown]
# ## Checkpoints (Object-based saving)

# %%
checkpoint_dir = './training_nmt_checkpoints'

checkpoint_prefix = os.path.join(checkpoint_dir, "ckpt")

checkpoint = tf.train.Checkpoint(optimizer=optimizer,
                                 encoder=encoder,
                                 decoder=decoder)

# %%
@tf.function
def train_step(inp, targ, enc_hidden):
  loss = 0

  with tf.GradientTape() as tape:
    enc_hidden = encoder(inp, enc_hidden)

    forward_hidden, backward_hidden = enc_hidden

    dec_input = tf.expand_dims([targ_lang.word_index['<start>']] * BATCH_SIZE, 1)

    # Teacher forcing - feeding the target as the next input
    for t in range(1, targ.shape[1]): # Максимальная длина последовательности
      # passing enc_output to the decoder
      predictions, dec_hidden = decoder(dec_input, forward_hidden, backward_hidden)

      # считаем лосс по каждому предсказанному слову
      loss += loss_function(targ[:, t], predictions)

      # using teacher forcing
      dec_input = tf.expand_dims(targ[:, t], 1)

  batch_loss = (loss / int(targ.shape[1]))

  variables = encoder.trainable_variables + decoder.trainable_variables

  gradients = tape.gradient(loss, variables)

  optimizer.apply_gradients(zip(gradients, variables))

  return batch_loss

# %%
EPOCHS = 25

for epoch in range(EPOCHS):
  start = time.time()

  enc_hidden = encoder.initialize_hidden_state()
  total_loss = 0

  for (batch, (inp, targ)) in enumerate(dataset.take(steps_per_epoch)):
    batch_loss = train_step(inp, targ, enc_hidden)
    total_loss += batch_loss

    if batch % 100 == 0:
      print('Epoch {} Batch {} Loss {:.4f}'.format(epoch + 1,
                                                   batch,
                                                   batch_loss.numpy()))
  # saving (checkpoint) the model every 2 epochs
  if (epoch + 1) % 2 == 0:
    checkpoint.save(file_prefix = checkpoint_prefix)

  print('Epoch {} Loss {:.4f}'.format(epoch + 1,
                                      total_loss / steps_per_epoch))
  print('Time taken for 1 epoch {} sec\n'.format(time.time() - start))
# Out:
# Epoch 1 Batch 0 Loss 5.1608
# Epoch 1 Batch 100 Loss 2.2184
# Epoch 1 Batch 200 Loss 2.0267
# Epoch 1 Batch 300 Loss 1.6114
# Epoch 1 Batch 400 Loss 1.4174
# Epoch 1 Batch 500 Loss 1.2636
# Epoch 1 Batch 600 Loss 1.1658
# Epoch 1 Batch 700 Loss 1.1763
# Epoch 1 Batch 800 Loss 1.1824
# Epoch 1 Batch 900 Loss 0.9994
# Epoch 1 Batch 1000 Loss 1.0142
# Epoch 1 Batch 1100 Loss 0.7670
# Epoch 1 Batch 1200 Loss 0.9498
# Epoch 1 Loss 1.4006
# Time taken for 1 epoch 135.05229997634888 sec
#
# Epoch 2 Batch 0 Loss 0.6854
# Epoch 2 Batch 100 Loss 0.5698
# Epoch 2 Batch 200 Loss 0.7336
# Epoch 2 Batch 300 Loss 0.6156
# Epoch 2 Batch 400 Loss 0.5873
# Epoch 2 Batch 500 Loss 0.6513
# Epoch 2 Batch 600 Loss 0.6264
# Epoch 2 Batch 700 Loss 0.4877
# Epoch 2 Batch 800 Loss 0.6178
# Epoch 2 Batch 900 Loss 0.5067
# Epoch 2 Batch 1000 Loss 0.5014
# Epoch 2 Batch 1100 Loss 0.5745
# Epoch 2 Batch 1200 Loss 0.4105
# Epoch 2 Loss 0.5674
# Time taken for 1 epoch 119.46236610412598 sec
#
# Epoch 3 Batch 0 Loss 0.2577
# Epoch 3 Batch 100 Loss 0.2479
# Epoch 3 Batch 200 Loss 0.2448
# Epoch 3 Batch 300 Loss 0.3089
# Epoch 3 Batch 400 Loss 0.2403
# Epoch 3 Batch 500 Loss 0.3217
# Epoch 3 Batch 600 Loss 0.3394
# Epoch 3 Batch 700 Loss 0.3452
# Epoch 3 Batch 800 Loss 0.3330
# Epoch 3 Batch 900 Loss 0.3122
# Epoch 3 Batch 1000 Loss 0.3121
# Epoch 3 Batch 1100 Loss 0.2509
# Epoch 3 Batch 1200 Loss 0.3600
# Epoch 3 Loss 0.2989
# Time taken for 1 epoch 117.16297006607056 sec
#
# Epoch 4 Batch 0 Loss 0.1533
# Epoch 4 Batch 100 Loss 0.1422
# Epoch 4 Batch 200 Loss 0.1382
# Epoch 4 Batch 300 Loss 0.2072
# Epoch 4 Batch 400 Loss 0.1834
# Epoch 4 Batch 500 Loss 0.1799
# Epoch 4 Batch 600 Loss 0.1948
# Epoch 4 Batch 700 Loss 0.2736
# Epoch 4 Batch 800 Loss 0.1711
# Epoch 4 Batch 900 Loss 0.1618
# Epoch 4 Batch 1000 Loss 0.2252
# Epoch 4 Batch 1100 Loss 0.2326
# Epoch 4 Batch 1200 Loss 0.1824
# Epoch 4 Loss 0.1923
# Time taken for 1 epoch 125.07498049736023 sec
#
# Epoch 5 Batch 0 Loss 0.1549
# Epoch 5 Batch 100 Loss 0.1294
# Epoch 5 Batch 200 Loss 0.1586
# Epoch 5 Batch 300 Loss 0.1305
# Epoch 5 Batch 400 Loss 0.1237
# Epoch 5 Batch 500 Loss 0.1205
# Epoch 5 Batch 600 Loss 0.1420
# Epoch 5 Batch 700 Loss 0.1770
# Epoch 5 Batch 800 Loss 0.1488
# Epoch 5 Batch 900 Loss 0.1277
# Epoch 5 Batch 1000 Loss 0.1354
# Epoch 5 Batch 1100 Loss 0.1372
# Epoch 5 Batch 1200 Loss 0.1774
# Epoch 5 Loss 0.1484
# Time taken for 1 epoch 117.02089858055115 sec
#
# Epoch 6 Batch 0 Loss 0.0868
# Epoch 6 Batch 100 Loss 0.0862
# Epoch 6 Batch 200 Loss 0.1136
# Epoch 6 Batch 300 Loss 0.1086
# Epoch 6 Batch 400 Loss 0.0709
# Epoch 6 Batch 500 Loss 0.1804
# Epoch 6 Batch 600 Loss 0.1359
# Epoch 6 Batch 700 Loss 0.0909
# Epoch 6 Batch 800 Loss 0.1669
# Epoch 6 Batch 900 Loss 0.1258
# Epoch 6 Batch 1000 Loss 0.0977
# Epoch 6 Batch 1100 Loss 0.1896
# Epoch 6 Batch 1200 Loss 0.1954
# Epoch 6 Loss 0.1254
# Time taken for 1 epoch 123.66078853607178 sec
#
# Epoch 7 Batch 0 Loss 0.1340
# Epoch 7 Batch 100 Loss 0.1006
# Epoch 7 Batch 200 Loss 0.0789
# Epoch 7 Batch 300 Loss 0.0970
# Epoch 7 Batch 400 Loss 0.1113
# Epoch 7 Batch 500 Loss 0.1383
# Epoch 7 Batch 600 Loss 0.1226
# Epoch 7 Batch 700 Loss 0.1233
# Epoch 7 Batch 800 Loss 0.1093
# Epoch 7 Batch 900 Loss 0.1341
# Epoch 7 Batch 1000 Loss 0.1292
# Epoch 7 Batch 1100 Loss 0.1719
# Epoch 7 Batch 1200 Loss 0.1324
# Epoch 7 Loss 0.1140
# Time taken for 1 epoch 116.8625967502594 sec
#
# Epoch 8 Batch 0 Loss 0.0868
# Epoch 8 Batch 100 Loss 0.0535
# Epoch 8 Batch 200 Loss 0.0757
# Epoch 8 Batch 300 Loss 0.0996
# Epoch 8 Batch 400 Loss 0.0573
# Epoch 8 Batch 500 Loss 0.0567
# Epoch 8 Batch 600 Loss 0.0687
# Epoch 8 Batch 700 Loss 0.1263
# Epoch 8 Batch 800 Loss 0.1540
# Epoch 8 Batch 900 Loss 0.0815
# Epoch 8 Batch 1000 Loss 0.1098
# Epoch 8 Batch 1100 Loss 0.1091
# Epoch 8 Batch 1200 Loss 0.1167
# Epoch 8 Loss 0.1052
# Time taken for 1 epoch 127.8001799583435 sec
#
# Epoch 9 Batch 0 Loss 0.0554
# Epoch 9 Batch 100 Loss 0.1324
# Epoch 9 Batch 200 Loss 0.1052
# Epoch 9 Batch 300 Loss 0.0362
# Epoch 9 Batch 400 Loss 0.1083
# Epoch 9 Batch 500 Loss 0.1300
# Epoch 9 Batch 600 Loss 0.1520
# Epoch 9 Batch 700 Loss 0.1479
# Epoch 9 Batch 800 Loss 0.1187
# Epoch 9 Batch 900 Loss 0.1089
# Epoch 9 Batch 1000 Loss 0.1119
# Epoch 9 Batch 1100 Loss 0.1195
# Epoch 9 Batch 1200 Loss 0.1082
# Epoch 9 Loss 0.0967
# Time taken for 1 epoch 117.01497602462769 sec
#
# Epoch 10 Batch 0 Loss 0.0603
# Epoch 10 Batch 100 Loss 0.0744
# Epoch 10 Batch 200 Loss 0.1602
# Epoch 10 Batch 300 Loss 0.0732
# Epoch 10 Batch 400 Loss 0.0556
# Epoch 10 Batch 500 Loss 0.0792
# Epoch 10 Batch 600 Loss 0.1280
# Epoch 10 Batch 700 Loss 0.0723
# Epoch 10 Batch 800 Loss 0.1131
# Epoch 10 Batch 900 Loss 0.0795
# Epoch 10 Batch 1000 Loss 0.1660
# Epoch 10 Batch 1100 Loss 0.1179
# Epoch 10 Batch 1200 Loss 0.1178
# Epoch 10 Loss 0.0922
# Time taken for 1 epoch 123.74499559402466 sec
#
# Epoch 11 Batch 0 Loss 0.0621
# Epoch 11 Batch 100 Loss 0.0850
# Epoch 11 Batch 200 Loss 0.1002
# Epoch 11 Batch 300 Loss 0.0632
# Epoch 11 Batch 400 Loss 0.0656
# Epoch 11 Batch 500 Loss 0.0811
# Epoch 11 Batch 600 Loss 0.0631
# Epoch 11 Batch 700 Loss 0.0982
# Epoch 11 Batch 800 Loss 0.0859
# Epoch 11 Batch 900 Loss 0.1111
# Epoch 11 Batch 1000 Loss 0.0749
# Epoch 11 Batch 1100 Loss 0.1434
# Epoch 11 Batch 1200 Loss 0.0969
# Epoch 11 Loss 0.0879
# Time taken for 1 epoch 117.03382992744446 sec
#
# Epoch 12 Batch 0 Loss 0.0465
# Epoch 12 Batch 100 Loss 0.0669
# Epoch 12 Batch 200 Loss 0.0625
# Epoch 12 Batch 300 Loss 0.0591
# Epoch 12 Batch 400 Loss 0.0607
# Epoch 12 Batch 500 Loss 0.0879
# Epoch 12 Batch 600 Loss 0.0612
# Epoch 12 Batch 700 Loss 0.0754
# Epoch 12 Batch 800 Loss 0.0498
# Epoch 12 Batch 900 Loss 0.1464
# Epoch 12 Batch 1000 Loss 0.1167
# Epoch 12 Batch 1100 Loss 0.0958
# Epoch 12 Batch 1200 Loss 0.1091
# Epoch 12 Loss 0.0842
# Time taken for 1 epoch 124.75985527038574 sec
#
# Epoch 13 Batch 0 Loss 0.0268
# Epoch 13 Batch 100 Loss 0.0343
# Epoch 13 Batch 200 Loss 0.0693
# Epoch 13 Batch 300 Loss 0.0902
# Epoch 13 Batch 400 Loss 0.0837
# Epoch 13 Batch 500 Loss 0.0641
# Epoch 13 Batch 600 Loss 0.0640
# Epoch 13 Batch 700 Loss 0.0896
# Epoch 13 Batch 800 Loss 0.0900
# Epoch 13 Batch 900 Loss 0.1072
# Epoch 13 Batch 1000 Loss 0.0857
# Epoch 13 Batch 1100 Loss 0.0660
# Epoch 13 Batch 1200 Loss 0.1151
# Epoch 13 Loss 0.0804
# Time taken for 1 epoch 116.89638113975525 sec
#
# Epoch 14 Batch 0 Loss 0.0297
# Epoch 14 Batch 100 Loss 0.0717
# Epoch 14 Batch 200 Loss 0.1044
# Epoch 14 Batch 300 Loss 0.1151
# Epoch 14 Batch 400 Loss 0.0506
# Epoch 14 Batch 500 Loss 0.0521
# Epoch 14 Batch 600 Loss 0.0639
# Epoch 14 Batch 700 Loss 0.1135
# Epoch 14 Batch 800 Loss 0.0828
# Epoch 14 Batch 900 Loss 0.1054
# Epoch 14 Batch 1000 Loss 0.0673
# Epoch 14 Batch 1100 Loss 0.1246
# Epoch 14 Batch 1200 Loss 0.1580
# Epoch 14 Loss 0.0769
# Time taken for 1 epoch 127.86419916152954 sec
#
# Epoch 15 Batch 0 Loss 0.0762
# Epoch 15 Batch 100 Loss 0.0646
# Epoch 15 Batch 200 Loss 0.0752
# Epoch 15 Batch 300 Loss 0.0580
# Epoch 15 Batch 400 Loss 0.0474
# Epoch 15 Batch 500 Loss 0.0693
# Epoch 15 Batch 600 Loss 0.0524
# Epoch 15 Batch 700 Loss 0.0638
# Epoch 15 Batch 800 Loss 0.0816
# Epoch 15 Batch 900 Loss 0.0689
# Epoch 15 Batch 1000 Loss 0.0683
# Epoch 15 Batch 1100 Loss 0.1226
# Epoch 15 Batch 1200 Loss 0.0720
# Epoch 15 Loss 0.0752
# Time taken for 1 epoch 117.04428172111511 sec
#
# Epoch 16 Batch 0 Loss 0.0893
# Epoch 16 Batch 100 Loss 0.0957
# Epoch 16 Batch 200 Loss 0.0919
# Epoch 16 Batch 300 Loss 0.0793
# Epoch 16 Batch 400 Loss 0.0367
# Epoch 16 Batch 500 Loss 0.0530
# Epoch 16 Batch 600 Loss 0.0462
# Epoch 16 Batch 700 Loss 0.0806
# Epoch 16 Batch 800 Loss 0.0872
# Epoch 16 Batch 900 Loss 0.0956
# Epoch 16 Batch 1000 Loss 0.0526
# Epoch 16 Batch 1100 Loss 0.0788
# Epoch 16 Batch 1200 Loss 0.0657
# Epoch 16 Loss 0.0728
# Time taken for 1 epoch 127.89386534690857 sec
#
# Epoch 17 Batch 0 Loss 0.0776
# Epoch 17 Batch 100 Loss 0.0725
# Epoch 17 Batch 200 Loss 0.0483
# Epoch 17 Batch 300 Loss 0.0794
# Epoch 17 Batch 400 Loss 0.0452
# Epoch 17 Batch 500 Loss 0.0699
# Epoch 17 Batch 600 Loss 0.0964
# Epoch 17 Batch 700 Loss 0.0557
# Epoch 17 Batch 800 Loss 0.0926
# Epoch 17 Batch 900 Loss 0.0607
# Epoch 17 Batch 1000 Loss 0.0420
# Epoch 17 Batch 1100 Loss 0.0934
# Epoch 17 Batch 1200 Loss 0.1186
# Epoch 17 Loss 0.0705
# Time taken for 1 epoch 116.9744827747345 sec
#
# Epoch 18 Batch 0 Loss 0.0808
# Epoch 18 Batch 100 Loss 0.0641
# Epoch 18 Batch 200 Loss 0.0699
# Epoch 18 Batch 300 Loss 0.0747
# Epoch 18 Batch 400 Loss 0.0525
# Epoch 18 Batch 500 Loss 0.0350
# Epoch 18 Batch 600 Loss 0.0846
# Epoch 18 Batch 700 Loss 0.0774
# Epoch 18 Batch 800 Loss 0.0824
# Epoch 18 Batch 900 Loss 0.0558
# Epoch 18 Batch 1000 Loss 0.0834
# Epoch 18 Batch 1100 Loss 0.0688
# Epoch 18 Batch 1200 Loss 0.0721
# Epoch 18 Loss 0.0686
# Time taken for 1 epoch 123.69283246994019 sec
#
# Epoch 19 Batch 0 Loss 0.0886
# Epoch 19 Batch 100 Loss 0.0463
# Epoch 19 Batch 200 Loss 0.0515
# Epoch 19 Batch 300 Loss 0.0360
# Epoch 19 Batch 400 Loss 0.0532
# Epoch 19 Batch 500 Loss 0.0702
# Epoch 19 Batch 600 Loss 0.0584
# Epoch 19 Batch 700 Loss 0.0331
# Epoch 19 Batch 800 Loss 0.0815
# Epoch 19 Batch 900 Loss 0.0823
# Epoch 19 Batch 1000 Loss 0.0868
# Epoch 19 Batch 1100 Loss 0.0734
# Epoch 19 Batch 1200 Loss 0.0756
# Epoch 19 Loss 0.0664
# Time taken for 1 epoch 116.93382477760315 sec
#
# Epoch 20 Batch 0 Loss 0.0556
# Epoch 20 Batch 100 Loss 0.0543
# Epoch 20 Batch 200 Loss 0.0309
# Epoch 20 Batch 300 Loss 0.0993
# Epoch 20 Batch 400 Loss 0.0662
# Epoch 20 Batch 500 Loss 0.0751
# Epoch 20 Batch 600 Loss 0.0656
# Epoch 20 Batch 700 Loss 0.0570
# Epoch 20 Batch 800 Loss 0.0636
# Epoch 20 Batch 900 Loss 0.0760
# Epoch 20 Batch 1000 Loss 0.0912
# Epoch 20 Batch 1100 Loss 0.0487
# Epoch 20 Batch 1200 Loss 0.1132
# Epoch 20 Loss 0.0658
# Time taken for 1 epoch 123.69069194793701 sec
#
# Epoch 21 Batch 0 Loss 0.0690
# Epoch 21 Batch 100 Loss 0.0310
# Epoch 21 Batch 200 Loss 0.0530
# Epoch 21 Batch 300 Loss 0.0384
# Epoch 21 Batch 400 Loss 0.0462
# Epoch 21 Batch 500 Loss 0.0565
# Epoch 21 Batch 600 Loss 0.0818
# Epoch 21 Batch 700 Loss 0.0581
# Epoch 21 Batch 800 Loss 0.0324
# Epoch 21 Batch 900 Loss 0.0515
# Epoch 21 Batch 1000 Loss 0.0497
# Epoch 21 Batch 1100 Loss 0.0653
# Epoch 21 Batch 1200 Loss 0.0639
# Epoch 21 Loss 0.0636
# Time taken for 1 epoch 116.73312592506409 sec
#
# Epoch 22 Batch 0 Loss 0.0512
# Epoch 22 Batch 100 Loss 0.0392
# Epoch 22 Batch 200 Loss 0.0726
# Epoch 22 Batch 300 Loss 0.0420
# Epoch 22 Batch 400 Loss 0.0713
# Epoch 22 Batch 500 Loss 0.0596
# Epoch 22 Batch 600 Loss 0.0460
# Epoch 22 Batch 700 Loss 0.0599
# Epoch 22 Batch 800 Loss 0.0249
# Epoch 22 Batch 900 Loss 0.0677
# Epoch 22 Batch 1000 Loss 0.0500
# Epoch 22 Batch 1100 Loss 0.0377
# Epoch 22 Batch 1200 Loss 0.0557
# Epoch 22 Loss 0.0620
# Time taken for 1 epoch 118.99313926696777 sec
#
# Epoch 23 Batch 0 Loss 0.0576
# Epoch 23 Batch 100 Loss 0.0433
# Epoch 23 Batch 200 Loss 0.0747
# Epoch 23 Batch 300 Loss 0.0381
# Epoch 23 Batch 400 Loss 0.0618
# Epoch 23 Batch 500 Loss 0.0640
# Epoch 23 Batch 600 Loss 0.0865
# Epoch 23 Batch 700 Loss 0.0560
# Epoch 23 Batch 800 Loss 0.0897
# Epoch 23 Batch 900 Loss 0.0926
# Epoch 23 Batch 1000 Loss 0.0868
# Epoch 23 Batch 1100 Loss 0.0739
# Epoch 23 Batch 1200 Loss 0.0699
# Epoch 23 Loss 0.0613
# Time taken for 1 epoch 116.90514183044434 sec
#
# Epoch 24 Batch 0 Loss 0.0484
# Epoch 24 Batch 100 Loss 0.0415
# Epoch 24 Batch 200 Loss 0.0472
# Epoch 24 Batch 300 Loss 0.0535
# Epoch 24 Batch 400 Loss 0.0592
# Epoch 24 Batch 500 Loss 0.0382
# Epoch 24 Batch 600 Loss 0.0466
# Epoch 24 Batch 700 Loss 0.0980
# Epoch 24 Batch 800 Loss 0.0418
# Epoch 24 Batch 900 Loss 0.0725
# Epoch 24 Batch 1000 Loss 0.0406
# Epoch 24 Batch 1100 Loss 0.1163
# Epoch 24 Batch 1200 Loss 0.0666
# Epoch 24 Loss 0.0603
# Time taken for 1 epoch 123.81846308708191 sec
#
# Epoch 25 Batch 0 Loss 0.0498
# Epoch 25 Batch 100 Loss 0.0426
# Epoch 25 Batch 200 Loss 0.0860
# Epoch 25 Batch 300 Loss 0.0454
# Epoch 25 Batch 400 Loss 0.1086
# Epoch 25 Batch 500 Loss 0.0465
# Epoch 25 Batch 600 Loss 0.0510
# Epoch 25 Batch 700 Loss 0.0553
# Epoch 25 Batch 800 Loss 0.0839
# Epoch 25 Batch 900 Loss 0.0809
# Epoch 25 Batch 1000 Loss 0.0793
# Epoch 25 Batch 1100 Loss 0.0589
# Epoch 25 Batch 1200 Loss 0.0702
# Epoch 25 Loss 0.0593
# Time taken for 1 epoch 116.84280252456665 sec

# %% [markdown]
# ## Translate
#
# * The evaluate function is similar to the training loop, except we don't use *teacher forcing* here. The input to the decoder at each time step is its previous predictions along with the hidden state and the encoder output.
# * Stop predicting when the model predicts the *end token*.
# * And store the *attention weights for every time step*.
#
# Note: The encoder output is calculated only once for one input.

# %%
def evaluate(sentence):
  attention_plot = np.zeros((max_length_targ, max_length_inp))

  sentence = preprocess_sentence(sentence)

  inputs = [inp_lang.word_index[i] for i in sentence.split(' ')]
  inputs = tf.keras.preprocessing.sequence.pad_sequences([inputs],
                                                         maxlen=max_length_inp,
                                                         padding='post')
  inputs = tf.convert_to_tensor(inputs)

  result = ''

  hidden = [tf.zeros((1, units)) for i in range(2)]
  enc_hidden = encoder(inputs, hidden)

  forward_hidden, backward_hidden = enc_hidden

  dec_input = tf.expand_dims([targ_lang.word_index['<start>']], 0)

  for t in range(max_length_targ):
    predictions, dec_hidden = decoder(dec_input, forward_hidden, backward_hidden)

    # storing the attention weights to plot later on
    predicted_id = tf.argmax(predictions[0]).numpy()
    result += targ_lang.index_word[predicted_id] + ' '

    if targ_lang.index_word[predicted_id] == '<end>':
      return result, sentence

    # the predicted ID is fed back into the model
    dec_input = tf.expand_dims([predicted_id], 0)

  return result, sentence

# %%
def translate(sentence):
  result, sentence = evaluate(sentence)

  print('Input: %s' % (sentence))
  print('Predicted translation: {}'.format(result))

# %% [markdown]
# ## Restore the latest checkpoint and test

# %%
# restoring the latest checkpoint in checkpoint_dir
# checkpoint.restore(tf.train.latest_checkpoint(checkpoint_dir))

# %%
translate('Здесь хорошо.')
# Out:
# Input: <start> здесь хорошо . <end>
# Predicted translation: it's good here . <end>

# %%
translate('Я не смогу поехать.')
# Out:
# Input: <start> я не смогу поехать . <end>
# Predicted translation: i can't go . <end>

# %%
translate(u'Вы еще дома?')
# Out:
# Input: <start> вы еще дома ? <end>
# Predicted translation: are you still home ? <end>

# %%
translate(u'Вы всё еще дома?')
# Out:
# Input: <start> вы вс еще дома ? <end>
# Predicted translation: are you still home ? <end>

# %%
translate(u'Попробуй сделать это.')
# Out:
# Input: <start> попробуй сделать это . <end>
# Predicted translation: try to do it . <end>

# %%
translate(u'Я люблю, когда идет снег.')
# Out:
# Input: <start> я люблю , когда идет снег . <end>
# Predicted translation: i like when it rains . <end>

# %%
translate(u'Я никогда такого не делаю.')
# Out:
# Input: <start> я никогда такого не делаю . <end>
# Predicted translation: i never do that . <end>

# %%
translate('Я хочу поехать в отпуск.')
# Out:
# Input: <start> я хочу поехать в отпуск . <end>
# Predicted translation: i want to go to go to go to go

# %%
translate('Я тебя люблю')
# Out:
# Input: <start> я тебя люблю <end>
# Predicted translation: i love you . <end>

# %%
translate('У меня есть собака')
# Out:
# Input: <start> у меня есть собака <end>
# Predicted translation: i have a dog . <end>

# %%
translate('Как у тебя дела?')
# Out:
# Input: <start> как у тебя дела ? <end>
# Predicted translation: how are you doing ? <end>

# %%
translate('Жизнь прекрасна')
# Out:
# Input: <start> жизнь прекрасна <end>
# Predicted translation: life is sweet . <end>

# %%
translate(u'Когда у тебя день рождения?')
# Out:
# Input: <start> когда у тебя день рождения ? <end>
# Predicted translation: when is your day ? <end>

# %%
translate(u'Как твое ничего?')
# Out:
# Input: <start> как твое ничего ? <end>
# Predicted translation: how are you ? <end>

# %% [markdown]
# В целом не так плохо
